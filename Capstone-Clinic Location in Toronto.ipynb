# %% [markdown]
# <h1> Finding out Best Neighborhood to open a Clinic In Toronto </h1>

# %% [markdown]
# <h2> Data Preparation </h2>

# %%
#defing URL to scrape
url_wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
url_wiki
# Out:
# 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
#Scraping the data and tabulating
import pandas as pd

pd_page = pd.read_html(url_wiki)

df_TOR = pd_page[0]
df_TOR.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df_TOR.shape
# Out:
# (288, 3)

# %%
df_TOR['Borough'].unique()
# Out:
# array(['Not assigned', 'North York', 'Downtown Toronto', "Queen's Park",
#        'Etobicoke', 'Scarborough', 'East York', 'York', 'East Toronto',
#        'West Toronto', 'Central Toronto', 'Mississauga'], dtype=object)

# %%
df_TOR.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
print('Number of "Not assigned" in Neighbourhood, before: ',df_TOR[df_TOR['Neighbourhood']=='Not assigned'].count()['Postcode'])

for i, row in df_TOR.iterrows():
    if row.Neighbourhood == 'Not assigned':
        row.Neighbourhood = row.Borough

print('Number of "Not assigned" in Neighbourhood, after: ',df_TOR[df_TOR['Neighbourhood']=='Not assigned'].count()['Postcode'])
# Out:
# Number of "Not assigned" in Neighbourhood, before:  78
# Number of "Not assigned" in Neighbourhood, after:  77

# %%
#info before combining neighbourhoods which have the same postcode
print('Number of postcodes: ',len(df_TOR['Postcode'].unique()))
print('Number of total neighbourhoods: ', df_TOR.shape[0])
# Out:
# Number of postcodes:  180
# Number of total neighbourhoods:  288

# %%
#set temporary parameters for saving data
last_postcode = ''
last_borough = ''
last_neighbourhood = ''

#processing
for i, row in df_TOR.iterrows():
    if row.Postcode == last_postcode and row.Borough == last_borough:
        row.Neighbourhood = last_neighbourhood + ', ' + row.Neighbourhood
        #print('stop at ',i) #for debugging
        df_TOR.iloc[i-1]['Neighbourhood'] = 'NA'
    last_postcode = row.Postcode
    last_borough = row.Borough
    last_neighbourhood = row.Neighbourhood
    #print(i, postcode_before, borough_before, neighbourhood_before) #for debugging

df_TOR.head(5)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto                NA

# %%
df_TOR.tail(5)
# Out:
#     Postcode       Borough                                      Neighbourhood
# 283      M8Z     Etobicoke                                                 NA
# 284      M8Z     Etobicoke                                                 NA
# 285      M8Z     Etobicoke                                                 NA
# 286      M8Z     Etobicoke  Kingsway Park South West, Mimico NW, The Queen...
# 287      M9Z  Not assigned                                       Not assigned

# %%
df_TOR = df_TOR[df_TOR['Neighbourhood'] != 'NA']

# %%
df_TOR.reset_index(drop=True, inplace=True)
df_TOR.head()
# Out:
#   Postcode           Borough              Neighbourhood
# 0      M1A      Not assigned               Not assigned
# 1      M2A      Not assigned               Not assigned
# 2      M3A        North York                  Parkwoods
# 3      M4A        North York           Victoria Village
# 4      M5A  Downtown Toronto  Harbourfront, Regent Park

# %%
df_TOR.shape
# Out:
# (180, 3)

# %% [markdown]
# <h2> Getting Geospatial Data for Neighborhood </h2>

# %%
url_postcode_TOR = 'http://cocl.us/Geospatial_data'
url_postcode_TOR
# Out:
# 'http://cocl.us/Geospatial_data'

# %%
pd_postcode = pd.read_csv(url_postcode_TOR)
df_PC_TOR = pd.DataFrame(pd_postcode)
df_PC_TOR.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# <h2> Merging the 2 tables </h2>

# %%
df_merged = df_TOR
df_merged = df_merged.join(df_PC_TOR.set_index('Postal Code'), on='Postcode')
df_merged.head(10)
# Out:
#   Postcode           Borough                     Neighbourhood   Latitude  \
# 0      M1A      Not assigned                      Not assigned        NaN
# 1      M2A      Not assigned                      Not assigned        NaN
# 2      M3A        North York                         Parkwoods  43.753259
# 3      M4A        North York                  Victoria Village  43.725882
# 4      M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 5      M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 6      M7A      Queen's Park                      Queen's Park  43.662301
# 7      M8A      Not assigned                      Not assigned        NaN
# 8      M9A         Etobicoke                  Islington Avenue  43.667856
# 9      M1B       Scarborough                    Rouge, Malvern  43.806686
#
#    Longitude
# 0        NaN
# 1        NaN
# 2 -79.329656
# 3 -79.315572
# 4 -79.360636
# 5 -79.464763
# 6 -79.389494
# 7        NaN
# 8 -79.532242
# 9 -79.194353

# %%
df_filtered_TOR = df_merged[df_merged['Borough'].str.contains('Toronto')]
df_filtered_TOR.reset_index(drop=True, inplace=True)
df_filtered_TOR.head()
# Out:
#   Postcode           Borough              Neighbourhood   Latitude  Longitude
# 0      M5A  Downtown Toronto  Harbourfront, Regent Park  43.654260 -79.360636
# 1      M5B  Downtown Toronto   Ryerson, Garden District  43.657162 -79.378937
# 2      M5C  Downtown Toronto             St. James Town  43.651494 -79.375418
# 3      M4E      East Toronto                The Beaches  43.676357 -79.293031
# 4      M5E  Downtown Toronto                Berczy Park  43.644771 -79.373306

# %%
df_filtered_TOR.shape
# Out:
# (38, 5)

# %%
# install folium
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-3.1.0               |           py36_0         724 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         822 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.1.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-3.1.0         | 724 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
  import numpy as np # library to handle data in a vectorized manner

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans


import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <h2> Initializing Foursquare request type for Clincs around Toronto </h2>

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
search_query = 'Clinic'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Clinic .... OK!

# %%
CLIENT_ID = 'YQFF03YT4BOY32U4XIVELI3PUXTABGYD2W1AFDBHLWQFU1TV' # your Foursquare ID
CLIENT_SECRET = 'LLX3X4P1CXMWFTA4DLJJXZSY5U1MQIARDGLL3IECBNR4ZOTL' # your Foursquare Secret
VERSION = '20190804'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YQFF03YT4BOY32U4XIVELI3PUXTABGYD2W1AFDBHLWQFU1TV
# CLIENT_SECRET:LLX3X4P1CXMWFTA4DLJJXZSY5U1MQIARDGLL3IECBNR4ZOTL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=YQFF03YT4BOY32U4XIVELI3PUXTABGYD2W1AFDBHLWQFU1TV&client_secret=LLX3X4P1CXMWFTA4DLJJXZSY5U1MQIARDGLL3IECBNR4ZOTL&ll=43.653963,-79.387207&v=20190804&query=Clinic&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d492ff489b06a002c0566ce'},
#  'response': {'venues': [{'id': '4f6334e0e4b04d4b145f5b83',
#     'name': 'Transplant Clinic',
#     'location': {'lat': 43.657469381697524,
#      'lng': -79.38917767008937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657469381697524,
#        'lng': -79.38917767008937}],
#      'distance': 421,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4de68e89e4cde71744c308da',
#     'name': 'Rudd-PES Endoscopy Clinic',
#     'location': {'address': '123 Edward Street',
#      'lat': 43.65589356806434,
#      'lng': -79.38663756275383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65589356806434,
#        'lng': -79.38663756275383}],
#      'distance': 219,
#      'postalCode': 'M5G 1E2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward Street',
#       'Toronto ON M5G 1E2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '507ff5a8e4b03cfb613822e9',
#     'name': 'Clinic 9',
#     'location': {'address': 'The Hospital for Sick Children (SickKids)',
#      'lat': 43.657343342774865,
#      'lng': -79.38773168680045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657343342774865,
#        'lng': -79.38773168680045}],
#      'distance': 378,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['The Hospital for Sick Children (SickKids)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4b8e90ecf964a520122933e3',
#     'name': 'MCI Medical Clinic',
#     'location': {'address': '595 Bay St.',
#      'crossStreet': 'in Atrium on Bay',
#      'lat': 43.65613745484842,
#      'lng': -79.38345395206551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65613745484842,
#        'lng': -79.38345395206551}],
#      'distance': 387,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St. (in Atrium on Bay)',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '51c0df108bbd5e5f422621d1',
#     'name': 'Visage Clinic',
#     'location': {'address': '101-133 Hazelton Avenue',
#      'lat': 43.650725662509466,
#      'lng': -79.39122498035431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650725662509466,
#        'lng': -79.39122498035431}],
#      'distance': 484,
#      'postalCode': 'M5R 0A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['101-133 Hazelton Avenue',
#       'Toronto ON M5R 0A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '59006842'},
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '50c797b1e4b0c262e0d052f2',
#     'name': 'Princess Margaret Hospital- REACH Clinic',
#     'location': {'lat': 43.65791667887002,
#      'lng': -79.39049168093005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65791667887002,
#        'lng': -79.39049168093005}],
#      'distance': 513,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d194941735',
#       'name': 'Emergency Room',
#       'pluralName': 'Emergency Rooms',
#       'shortName': 'Emergency Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4c6062b612e5c9286e131f4c',
#     'name': 'Dundas University Health Clinic',
#     'location': {'address': '104-438 University Avenue',
#      'lat': 43.65419587934101,
#      'lng': -79.38816564112626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65419587934101,
#        'lng': -79.38816564112626}],
#      'distance': 81,
#      'postalCode': 'M4P 2K8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['104-438 University Avenue',
#       'Toronto ON M4P 2K8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5c00ef0933e1180039ab5ee1',
#     'name': 'Dundas West Chiropractic Clinic',
#     'location': {'address': '216 - 2238 Dundas Street West',
#      'lat': 43.65486576934723,
#      'lng': -79.38783645631247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65486576934723,
#        'lng': -79.38783645631247}],
#      'distance': 112,
#      'postalCode': 'M6R 3A9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['216 - 2238 Dundas Street West',
#       'Toronto ON M6R 3A9',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3a',
#       'name': 'Chiropractor',
#       'pluralName': 'Chiropractors',
#       'shortName': 'Chiropractors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5743113a498eb9c6237376ea',
#     'name': 'The Voice Clinic',
#     'location': {'address': '180 Dundas St W',
#      'lat': 43.6553678,
#      'lng': -79.38642920000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6553678,
#        'lng': -79.38642920000001}],
#      'distance': 168,
#      'postalCode': 'M7A 0A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['180 Dundas St W', 'Toronto ON M7A 0A1', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '192297230'},
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4bcdbdd8511f9521bf0eb5c7',
#     'name': 'Medisys Travel Health Clinic',
#     'location': {'address': '505, 123 Edward Street',
#      'lat': 43.65552956260831,
#      'lng': -79.38637365149951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65552956260831,
#        'lng': -79.38637365149951}],
#      'distance': 186,
#      'cc': 'CA',
#      'city': 'Toronto Division',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['505, 123 Edward Street',
#       'Toronto Division ON',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '565f1e82498e8c9f257e284f',
#     'name': 'Toronto Allergy Clinic',
#     'location': {'lat': 43.655708,
#      'lng': -79.38679,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655708,
#        'lng': -79.38679}],
#      'distance': 197,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5d2db634ceaba30023f39774',
#     'name': 'Cystoscopy Clinic',
#     'location': {'lat': 43.658806,
#      'lng': -79.389568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658806,
#        'lng': -79.389568}],
#      'distance': 571,
#      'postalCode': 'M5G 2N2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5G 2N2', 'Canada']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f7',
#       'name': 'Hospital Ward',
#       'pluralName': 'Hospital Wards',
#       'shortName': 'Hospital Ward',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4be2b974f07b0f47e6fff543',
#     'name': 'Mt Sinai Hospital; Rheumatology Clinic',
#     'location': {'lat': 43.6580952649394,
#      'lng': -79.39125038998642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6580952649394,
#        'lng': -79.39125038998642}],
#      'distance': 563,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4bec4821976ac9283bc8600b',
#     'name': 'Spine & Sport Physiotherapy Clinic',
#     'location': {'address': '123 Edward St, Ste 500',
#      'crossStreet': 'btw Centre & Chestnut',
#      'lat': 43.65379553862144,
#      'lng': -79.38445477412564,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65379553862144,
#        'lng': -79.38445477412564}],
#      'distance': 222,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward St, Ste 500 (btw Centre & Chestnut)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4af',
#       'name': 'Physical Therapist',
#       'pluralName': 'Physical Therapists',
#       'shortName': 'Physical Therapist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4b8e6624f964a520d32033e3',
#     'name': 'Medisys Travel Clinic',
#     'location': {'address': '123 Edward St, Suite 500',
#      'crossStreet': 'University + Dundas',
#      'lat': 43.655831,
#      'lng': -79.386579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655831,
#        'lng': -79.386579}],
#      'distance': 214,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward St, Suite 500 (University + Dundas)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5d139287c626c60023f64fd1',
#     'name': 'Gastrointestinal Clinic',
#     'location': {'lat': 43.658706,
#      'lng': -79.388775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658706,
#        'lng': -79.388775}],
#      'distance': 542,
#      'postalCode': 'M5G 0A3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5G 0A3', 'Canada']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f7',
#       'name': 'Hospital Ward',
#       'pluralName': 'Hospital Wards',
#       'shortName': 'Hospital Ward',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4bfeeacb369476b0490f8d1f',
#     'name': 'Albany Medical Clinic',
#     'location': {'lat': 43.650528745677136,
#      'lng': -79.3883474695189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650528745677136,
#        'lng': -79.3883474695189}],
#      'distance': 393,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5c697523e17910002cad7300',
#     'name': 'The Mindfulness Clinic',
#     'location': {'address': '700 Bay St',
#      'crossStreet': 'Suite 2200',
#      'lat': 43.652068640913996,
#      'lng': -79.3827223777771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652068640913996,
#        'lng': -79.3827223777771}],
#      'distance': 418,
#      'postalCode': 'M5G 1Z6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['700 Bay St (Suite 2200)',
#       'Toronto ON M5G 1Z6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '59145e7c28122f4841a9c34c',
#     'name': 'Toronto Foot Clinic',
#     'location': {'address': '483 Bay St',
#      'lat': 43.653187,
#      'lng': -79.382181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653187,
#        'lng': -79.382181}],
#      'distance': 413,
#      'postalCode': 'M5G 2A3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['483 Bay St', 'Toronto ON M5G 2A3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4f8dc001e4b0a7ee5a99a8a3',
#     'name': 'Blood Clinic',
#     'location': {'lat': 43.657531,
#      'lng': -79.389445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657531,
#        'lng': -79.389445}],
#      'distance': 436,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4e67aa9262e1706d82b38dbe',
#     'name': 'MSH Dental Clinic',
#     'location': {'address': '600 University Ave',
#      'lat': 43.65726180476912,
#      'lng': -79.39027726202539,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65726180476912,
#        'lng': -79.39027726202539}],
#      'distance': 442,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['600 University Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '50070255e4b0b976338d221f',
#     'name': 'Mt Sinai Hospital Voice Clinic (Pathology)',
#     'location': {'address': '600 University Ave',
#      'crossStreet': "Queen's Park",
#      'lat': 43.657508850097656,
#      'lng': -79.39029693603516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657508850097656,
#        'lng': -79.39029693603516}],
#      'distance': 466,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["600 University Ave (Queen's Park)",
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '589485d4a8b75947f5a7e3c9',
#     'name': 'Trio Fertility Clinic',
#     'location': {'address': '655 Bay St',
#      'lat': 43.657576,
#      'lng': -79.384026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657576,
#        'lng': -79.384026}],
#      'distance': 476,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['655 Bay St', 'Canada']},
#     'categories': [{'id': '56aa371be4b08b9a8d5734ff',
#       'name': 'Maternity Clinic',
#       'pluralName': 'Maternity Clinics',
#       'shortName': 'Maternity Clinic',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5086b15ae4b0b2d3848472a2',
#     'name': 'Mt. Sinai Fracture Clinic',
#     'location': {'lat': 43.65665817260742,
#      'lng': -79.39175415039062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65665817260742,
#        'lng': -79.39175415039062}],
#      'distance': 473,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '5abb355cc0f1630e680d6e86',
#     'name': 'Grow Legally Marijuana Clinic and Consulting',
#     'location': {'address': '1 Dundas Street West',
#      'crossStreet': 'Suite 2500C',
#      'lat': 43.6560430600055,
#      'lng': -79.38140273094176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6560430600055,
#        'lng': -79.38140273094176}],
#      'distance': 521,
#      'postalCode': 'M5G 1Z3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Dundas Street West (Suite 2500C)',
#       'Toronto ON M5G 1Z3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4e4ac4deb0fb37342ef36107',
#     'name': 'Ocular Oncology Clinic at Princess Margaret Hospital',
#     'location': {'address': '18th floor, 610 University Ave',
#      'lat': 43.65783070133404,
#      'lng': -79.39035423297143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65783070133404,
#        'lng': -79.39035423297143}],
#      'distance': 499,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18th floor, 610 University Ave',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '522deb22abdf65cfbab70d25',
#     'name': 'Tuina Health Clinic',
#     'location': {'address': '144 Yonge 2ndFlr',
#      'lat': 43.6551,
#      'lng': -79.3805,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.6551, 'lng': -79.3805}],
#      'distance': 554,
#      'postalCode': 'M5C 2L7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['144 Yonge 2ndFlr', 'Toronto ON M5C 2L7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '4be1c6f0edbb0f471ca7a615',
#     'name': 'Mt. Sinai Breastfeeding Clinic',
#     'location': {'lat': 43.65846249936535,
#      'lng': -79.389584520629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65846249936535,
#        'lng': -79.389584520629}],
#      'distance': 536,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '516eeef8498e01be6d9b842d',
#     'name': 'Hematology Clinic South (Princess Msrgaret Hospital)',
#     'location': {'address': '610 University Ave.',
#      'crossStreet': 'University & Murray St.',
#      'lat': 43.658671,
#      'lng': -79.390153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658671,
#        'lng': -79.390153}],
#      'distance': 575,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['610 University Ave. (University & Murray St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False},
#    {'id': '507ed74ce4b02081a0c556b3',
#     'name': 'Princess Margaret Hospital Transfusion Clinic (Blue)',
#     'location': {'lat': 43.65836249088483,
#      'lng': -79.3909974876591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65836249088483,
#        'lng': -79.3909974876591}],
#      'distance': 577,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565077492',
#     'hasPerk': False}]}}

# %% [markdown]
# <h3> Transform the JSON into Pandas Dataframe </h3>

# %%
# assign relevant part of JSON to venues
#venues = results1['response']['venues']

# tranform venues into a dataframe
#dataframe = json_normalize(venues)
#dataframe.head()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0                                                 []    False
# 1  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...    False
# 2  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...    False
# 4  [{'id': '4bf58dd8d48988d177941735', 'name': 'D...    False
#
#                          id                           location.address  \
# 0  4f6334e0e4b04d4b145f5b83                                        NaN
# 1  4de68e89e4cde71744c308da                          123 Edward Street
# 2  507ff5a8e4b03cfb613822e9  The Hospital for Sick Children (SickKids)
# 3  4b8e90ecf964a520122933e3                                595 Bay St.
# 4  51c0df108bbd5e5f422621d1                    101-133 Hazelton Avenue
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA           NaN           Canada                  NaN
# 1          CA       Toronto           Canada                  NaN
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada     in Atrium on Bay
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                421                                           [Canada]
# 1                219    [123 Edward Street, Toronto ON M5G 1E2, Canada]
# 2                378  [The Hospital for Sick Children (SickKids), To...
# 3                387  [595 Bay St. (in Atrium on Bay), Toronto ON M5...
# 4                484  [101-133 Hazelton Avenue, Toronto ON M5R 0A6, ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65746938169752...     43.657469
# 1  [{'label': 'display', 'lat': 43.65589356806434...     43.655894
# 2  [{'label': 'display', 'lat': 43.65734334277486...     43.657343
# 3  [{'label': 'display', 'lat': 43.65613745484842...     43.656137
# 4  [{'label': 'display', 'lat': 43.65072566250946...     43.650726
#
#    location.lng location.postalCode location.state                       name  \
# 0    -79.389178                 NaN            NaN          Transplant Clinic
# 1    -79.386638             M5G 1E2             ON  Rudd-PES Endoscopy Clinic
# 2    -79.387732                 NaN             ON                   Clinic 9
# 3    -79.383454             M5G 2C2             ON         MCI Medical Clinic
# 4    -79.391225             M5R 0A6             ON              Visage Clinic
#
#      referralId venuePage.id
# 0  v-1565077492          NaN
# 1  v-1565077492          NaN
# 2  v-1565077492          NaN
# 3  v-1565077492          NaN
# 4  v-1565077492     59006842

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                         name       categories  \
# 0          Transplant Clinic             None
# 1  Rudd-PES Endoscopy Clinic  Doctor's Office
# 2                   Clinic 9         Hospital
# 3         MCI Medical Clinic   Medical Center
# 4              Visage Clinic  Doctor's Office
#
#                                      address  cc     city country  \
# 0                                        NaN  CA      NaN  Canada
# 1                          123 Edward Street  CA  Toronto  Canada
# 2  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 3                                595 Bay St.  CA  Toronto  Canada
# 4                    101-133 Hazelton Avenue  CA  Toronto  Canada
#
#         crossStreet  distance  \
# 0               NaN       421
# 1               NaN       219
# 2               NaN       378
# 3  in Atrium on Bay       387
# 4               NaN       484
#
#                                     formattedAddress  \
# 0                                           [Canada]
# 1    [123 Edward Street, Toronto ON M5G 1E2, Canada]
# 2  [The Hospital for Sick Children (SickKids), To...
# 3  [595 Bay St. (in Atrium on Bay), Toronto ON M5...
# 4  [101-133 Hazelton Avenue, Toronto ON M5R 0A6, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65746938169752...  43.657469 -79.389178
# 1  [{'label': 'display', 'lat': 43.65589356806434...  43.655894 -79.386638
# 2  [{'label': 'display', 'lat': 43.65734334277486...  43.657343 -79.387732
# 3  [{'label': 'display', 'lat': 43.65613745484842...  43.656137 -79.383454
# 4  [{'label': 'display', 'lat': 43.65072566250946...  43.650726 -79.391225
#
#   postalCode state                        id
# 0        NaN   NaN  4f6334e0e4b04d4b145f5b83
# 1    M5G 1E2    ON  4de68e89e4cde71744c308da
# 2        NaN    ON  507ff5a8e4b03cfb613822e9
# 3    M5G 2C2    ON  4b8e90ecf964a520122933e3
# 4    M5R 0A6    ON  51c0df108bbd5e5f422621d1

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

for lat, lng, label in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['categories']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
display(venues_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dt=dataframe_filtered[['name','lat','lng','postalCode']]
dt.head()
# Out:
#                         name        lat        lng postalCode
# 0          Transplant Clinic  43.657469 -79.389178        NaN
# 1  Rudd-PES Endoscopy Clinic  43.655894 -79.386638    M5G 1E2
# 2                   Clinic 9  43.657343 -79.387732        NaN
# 3         MCI Medical Clinic  43.656137 -79.383454    M5G 2C2
# 4              Visage Clinic  43.650726 -79.391225    M5R 0A6

# %%
dt.dropna(subset = ['postalCode'])
# Out:
#                                             name        lat        lng  \
# 1                      Rudd-PES Endoscopy Clinic  43.655894 -79.386638
# 3                             MCI Medical Clinic  43.656137 -79.383454
# 4                                  Visage Clinic  43.650726 -79.391225
# 6                Dundas University Health Clinic  43.654196 -79.388166
# 7                Dundas West Chiropractic Clinic  43.654866 -79.387836
# 8                               The Voice Clinic  43.655368 -79.386429
# 11                             Cystoscopy Clinic  43.658806 -79.389568
# 15                       Gastrointestinal Clinic  43.658706 -79.388775
# 17                        The Mindfulness Clinic  43.652069 -79.382722
# 18                           Toronto Foot Clinic  43.653187 -79.382181
# 24  Grow Legally Marijuana Clinic and Consulting  43.656043 -79.381403
# 26                           Tuina Health Clinic  43.655100 -79.380500
#
#    postalCode
# 1     M5G 1E2
# 3     M5G 2C2
# 4     M5R 0A6
# 6     M4P 2K8
# 7     M6R 3A9
# 8     M7A 0A1
# 11    M5G 2N2
# 15    M5G 0A3
# 17    M5G 1Z6
# 18    M5G 2A3
# 24    M5G 1Z3
# 26    M5C 2L7

# %%
dt[['Postal Code','subcode']] = dt.postalCode.str.split(expand=True)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
dt
# Out:
#                                                  name        lat        lng  \
# 0                                   Transplant Clinic  43.657469 -79.389178
# 1                           Rudd-PES Endoscopy Clinic  43.655894 -79.386638
# 2                                            Clinic 9  43.657343 -79.387732
# 3                                  MCI Medical Clinic  43.656137 -79.383454
# 4                                       Visage Clinic  43.650726 -79.391225
# 5            Princess Margaret Hospital- REACH Clinic  43.657917 -79.390492
# 6                     Dundas University Health Clinic  43.654196 -79.388166
# 7                     Dundas West Chiropractic Clinic  43.654866 -79.387836
# 8                                    The Voice Clinic  43.655368 -79.386429
# 9                        Medisys Travel Health Clinic  43.655530 -79.386374
# 10                             Toronto Allergy Clinic  43.655708 -79.386790
# 11                                  Cystoscopy Clinic  43.658806 -79.389568
# 12             Mt Sinai Hospital; Rheumatology Clinic  43.658095 -79.391250
# 13                 Spine & Sport Physiotherapy Clinic  43.653796 -79.384455
# 14                              Medisys Travel Clinic  43.655831 -79.386579
# 15                            Gastrointestinal Clinic  43.658706 -79.388775
# 16                              Albany Medical Clinic  43.650529 -79.388347
# 17                             The Mindfulness Clinic  43.652069 -79.382722
# 18                                Toronto Foot Clinic  43.653187 -79.382181
# 19                                       Blood Clinic  43.657531 -79.389445
# 20                                  MSH Dental Clinic  43.657262 -79.390277
# 21         Mt Sinai Hospital Voice Clinic (Pathology)  43.657509 -79.390297
# 22                              Trio Fertility Clinic  43.657576 -79.384026
# 23                          Mt. Sinai Fracture Clinic  43.656658 -79.391754
# 24       Grow Legally Marijuana Clinic and Consulting  43.656043 -79.381403
# 25  Ocular Oncology Clinic at Princess Margaret Ho...  43.657831 -79.390354
# 26                                Tuina Health Clinic  43.655100 -79.380500
# 27                     Mt. Sinai Breastfeeding Clinic  43.658462 -79.389585
# 28  Hematology Clinic South (Princess Msrgaret Hos...  43.658671 -79.390153
# 29  Princess Margaret Hospital Transfusion Clinic ...  43.658362 -79.390997
#
#    postalCode Postal Code subcode
# 0         NaN         NaN     NaN
# 1     M5G 1E2         M5G     1E2
# 2         NaN         NaN     NaN
# 3     M5G 2C2         M5G     2C2
# 4     M5R 0A6         M5R     0A6
# 5         NaN         NaN     NaN
# 6     M4P 2K8         M4P     2K8
# 7     M6R 3A9         M6R     3A9
# 8     M7A 0A1         M7A     0A1
# 9         NaN         NaN     NaN
# 10        NaN         NaN     NaN
# 11    M5G 2N2         M5G     2N2
# 12        NaN         NaN     NaN
# 13        NaN         NaN     NaN
# 14        NaN         NaN     NaN
# 15    M5G 0A3         M5G     0A3
# 16        NaN         NaN     NaN
# 17    M5G 1Z6         M5G     1Z6
# 18    M5G 2A3         M5G     2A3
# 19        NaN         NaN     NaN
# 20        NaN         NaN     NaN
# 21        NaN         NaN     NaN
# 22        NaN         NaN     NaN
# 23        NaN         NaN     NaN
# 24    M5G 1Z3         M5G     1Z3
# 25        NaN         NaN     NaN
# 26    M5C 2L7         M5C     2L7
# 27        NaN         NaN     NaN
# 28        NaN         NaN     NaN
# 29        NaN         NaN     NaN

# %%
dt1=dt.dropna(subset = ['Postal Code'])
dt1
# Out:
#                                             name        lat        lng  \
# 1                      Rudd-PES Endoscopy Clinic  43.655894 -79.386638
# 3                             MCI Medical Clinic  43.656137 -79.383454
# 4                                  Visage Clinic  43.650726 -79.391225
# 6                Dundas University Health Clinic  43.654196 -79.388166
# 7                Dundas West Chiropractic Clinic  43.654866 -79.387836
# 8                               The Voice Clinic  43.655368 -79.386429
# 11                             Cystoscopy Clinic  43.658806 -79.389568
# 15                       Gastrointestinal Clinic  43.658706 -79.388775
# 17                        The Mindfulness Clinic  43.652069 -79.382722
# 18                           Toronto Foot Clinic  43.653187 -79.382181
# 24  Grow Legally Marijuana Clinic and Consulting  43.656043 -79.381403
# 26                           Tuina Health Clinic  43.655100 -79.380500
#
#    postalCode Postal Code subcode
# 1     M5G 1E2         M5G     1E2
# 3     M5G 2C2         M5G     2C2
# 4     M5R 0A6         M5R     0A6
# 6     M4P 2K8         M4P     2K8
# 7     M6R 3A9         M6R     3A9
# 8     M7A 0A1         M7A     0A1
# 11    M5G 2N2         M5G     2N2
# 15    M5G 0A3         M5G     0A3
# 17    M5G 1Z6         M5G     1Z6
# 18    M5G 2A3         M5G     2A3
# 24    M5G 1Z3         M5G     1Z3
# 26    M5C 2L7         M5C     2L7

# %%
df_PC_TOR.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# <h2> Merging Neighborhood Data with Foursqaure Data for Clinics </h2>

# %%
clinic_merged = df_TOR
clinic_merged = dt1.join(df_PC_TOR.set_index('Postal Code'), on='Postal Code')
clinic_merged.head(10)
# Out:
#                                name        lat        lng postalCode  \
# 1         Rudd-PES Endoscopy Clinic  43.655894 -79.386638    M5G 1E2
# 3                MCI Medical Clinic  43.656137 -79.383454    M5G 2C2
# 4                     Visage Clinic  43.650726 -79.391225    M5R 0A6
# 6   Dundas University Health Clinic  43.654196 -79.388166    M4P 2K8
# 7   Dundas West Chiropractic Clinic  43.654866 -79.387836    M6R 3A9
# 8                  The Voice Clinic  43.655368 -79.386429    M7A 0A1
# 11                Cystoscopy Clinic  43.658806 -79.389568    M5G 2N2
# 15          Gastrointestinal Clinic  43.658706 -79.388775    M5G 0A3
# 17           The Mindfulness Clinic  43.652069 -79.382722    M5G 1Z6
# 18              Toronto Foot Clinic  43.653187 -79.382181    M5G 2A3
#
#    Postal Code subcode   Latitude  Longitude
# 1          M5G     1E2  43.657952 -79.387383
# 3          M5G     2C2  43.657952 -79.387383
# 4          M5R     0A6  43.672710 -79.405678
# 6          M4P     2K8  43.712751 -79.390197
# 7          M6R     3A9  43.648960 -79.456325
# 8          M7A     0A1  43.662301 -79.389494
# 11         M5G     2N2  43.657952 -79.387383
# 15         M5G     0A3  43.657952 -79.387383
# 17         M5G     1Z6  43.657952 -79.387383
# 18         M5G     2A3  43.657952 -79.387383

# %%
clinic_merged2 = df_filtered_TOR
clinic_merged2 = dt1.join(df_filtered_TOR.set_index('Postcode'), on='Postal Code')
clinic_merged2.head(10)
# Out:
#                                name        lat        lng postalCode  \
# 1         Rudd-PES Endoscopy Clinic  43.655894 -79.386638    M5G 1E2
# 3                MCI Medical Clinic  43.656137 -79.383454    M5G 2C2
# 4                     Visage Clinic  43.650726 -79.391225    M5R 0A6
# 6   Dundas University Health Clinic  43.654196 -79.388166    M4P 2K8
# 7   Dundas West Chiropractic Clinic  43.654866 -79.387836    M6R 3A9
# 8                  The Voice Clinic  43.655368 -79.386429    M7A 0A1
# 11                Cystoscopy Clinic  43.658806 -79.389568    M5G 2N2
# 15          Gastrointestinal Clinic  43.658706 -79.388775    M5G 0A3
# 17           The Mindfulness Clinic  43.652069 -79.382722    M5G 1Z6
# 18              Toronto Foot Clinic  43.653187 -79.382181    M5G 2A3
#
#    Postal Code subcode           Borough                        Neighbourhood  \
# 1          M5G     1E2  Downtown Toronto                   Central Bay Street
# 3          M5G     2C2  Downtown Toronto                   Central Bay Street
# 4          M5R     0A6   Central Toronto  The Annex, North Midtown, Yorkville
# 6          M4P     2K8   Central Toronto                     Davisville North
# 7          M6R     3A9      West Toronto               Parkdale, Roncesvalles
# 8          M7A     0A1               NaN                                  NaN
# 11         M5G     2N2  Downtown Toronto                   Central Bay Street
# 15         M5G     0A3  Downtown Toronto                   Central Bay Street
# 17         M5G     1Z6  Downtown Toronto                   Central Bay Street
# 18         M5G     2A3  Downtown Toronto                   Central Bay Street
#
#      Latitude  Longitude
# 1   43.657952 -79.387383
# 3   43.657952 -79.387383
# 4   43.672710 -79.405678
# 6   43.712751 -79.390197
# 7   43.648960 -79.456325
# 8         NaN        NaN
# 11  43.657952 -79.387383
# 15  43.657952 -79.387383
# 17  43.657952 -79.387383
# 18  43.657952 -79.387383

# %%
clinic_merged3=clinic_merged2[['name','lat','lng','Postal Code','Borough','Neighbourhood']]
clinic_merged3
# Out:
#                                             name        lat        lng  \
# 1                      Rudd-PES Endoscopy Clinic  43.655894 -79.386638
# 3                             MCI Medical Clinic  43.656137 -79.383454
# 4                                  Visage Clinic  43.650726 -79.391225
# 6                Dundas University Health Clinic  43.654196 -79.388166
# 7                Dundas West Chiropractic Clinic  43.654866 -79.387836
# 8                               The Voice Clinic  43.655368 -79.386429
# 11                             Cystoscopy Clinic  43.658806 -79.389568
# 15                       Gastrointestinal Clinic  43.658706 -79.388775
# 17                        The Mindfulness Clinic  43.652069 -79.382722
# 18                           Toronto Foot Clinic  43.653187 -79.382181
# 24  Grow Legally Marijuana Clinic and Consulting  43.656043 -79.381403
# 26                           Tuina Health Clinic  43.655100 -79.380500
#
#    Postal Code           Borough                        Neighbourhood
# 1          M5G  Downtown Toronto                   Central Bay Street
# 3          M5G  Downtown Toronto                   Central Bay Street
# 4          M5R   Central Toronto  The Annex, North Midtown, Yorkville
# 6          M4P   Central Toronto                     Davisville North
# 7          M6R      West Toronto               Parkdale, Roncesvalles
# 8          M7A               NaN                                  NaN
# 11         M5G  Downtown Toronto                   Central Bay Street
# 15         M5G  Downtown Toronto                   Central Bay Street
# 17         M5G  Downtown Toronto                   Central Bay Street
# 18         M5G  Downtown Toronto                   Central Bay Street
# 24         M5G  Downtown Toronto                   Central Bay Street
# 26         M5C  Downtown Toronto                       St. James Town

# %%
clinic_merged3.to_csv('clinic_merged3.csv')

# %%
neigh_venue_summary = clinic_merged3.groupby('Neighbourhood').count()
neigh_venue_summary
# Out:
#                                      name  lat  lng  Postal Code  Borough
# Neighbourhood
# Central Bay Street                      7    7    7            7        7
# Davisville North                        1    1    1            1        1
# Parkdale, Roncesvalles                  1    1    1            1        1
# St. James Town                          1    1    1            1        1
# The Annex, North Midtown, Yorkville     1    1    1            1        1

# %% [markdown]
# <h2> Preparing DataFrame for Clustering </h2>

# %%
clinic_onehot = pd.get_dummies(data =clinic_merged3 , drop_first  = False, 
                              prefix = "", prefix_sep = "", columns = ['name'])
clinic_onehot.head()
# Out:
#          lat        lng Postal Code           Borough  \
# 1  43.655894 -79.386638         M5G  Downtown Toronto
# 3  43.656137 -79.383454         M5G  Downtown Toronto
# 4  43.650726 -79.391225         M5R   Central Toronto
# 6  43.654196 -79.388166         M4P   Central Toronto
# 7  43.654866 -79.387836         M6R      West Toronto
#
#                          Neighbourhood  Cystoscopy Clinic  \
# 1                   Central Bay Street                  0
# 3                   Central Bay Street                  0
# 4  The Annex, North Midtown, Yorkville                  0
# 6                     Davisville North                  0
# 7               Parkdale, Roncesvalles                  0
#
#    Dundas University Health Clinic  Dundas West Chiropractic Clinic  \
# 1                                0                                0
# 3                                0                                0
# 4                                0                                0
# 6                                1                                0
# 7                                0                                1
#
#    Gastrointestinal Clinic  Grow Legally Marijuana Clinic and Consulting  \
# 1                        0                                             0
# 3                        0                                             0
# 4                        0                                             0
# 6                        0                                             0
# 7                        0                                             0
#
#    MCI Medical Clinic  Rudd-PES Endoscopy Clinic  The Mindfulness Clinic  \
# 1                   0                          1                       0
# 3                   1                          0                       0
# 4                   0                          0                       0
# 6                   0                          0                       0
# 7                   0                          0                       0
#
#    The Voice Clinic  Toronto Foot Clinic  Tuina Health Clinic  Visage Clinic
# 1                 0                    0                    0              0
# 3                 0                    0                    0              0
# 4                 0                    0                    0              1
# 6                 0                    0                    0              0
# 7                 0                    0                    0              0

# %%
listoffeatures=['lat','lng','Neighbourhood','Borough','Rudd-PES Endoscopy Clinic',
                               'MCI Medical Clinic',
                                    'Visage Clinic',
                  'Dundas University Health Clinic',
                  'Dundas West Chiropractic Clinic',
                                 'The Voice Clinic',
                               'Cystoscopy Clinic',
                         'Gastrointestinal Clinic',
                          'The Mindfulness Clinic',
                             'Toronto Foot Clinic',
    'Grow Legally Marijuana Clinic and Consulting',
                             'Tuina Health Clinic']

# %%
clinic_onehot = clinic_onehot[listoffeatures].drop(
    columns = ['lat', 'lng','Borough']).groupby(
    'Neighbourhood').sum()


clinic_onehot.head()
# Out:
#                                      Rudd-PES Endoscopy Clinic  \
# Neighbourhood
# Central Bay Street                                           1
# Davisville North                                             0
# Parkdale, Roncesvalles                                       0
# St. James Town                                               0
# The Annex, North Midtown, Yorkville                          0
#
#                                      MCI Medical Clinic  Visage Clinic  \
# Neighbourhood
# Central Bay Street                                    1              0
# Davisville North                                      0              0
# Parkdale, Roncesvalles                                0              0
# St. James Town                                        0              0
# The Annex, North Midtown, Yorkville                   0              1
#
#                                      Dundas University Health Clinic  \
# Neighbourhood
# Central Bay Street                                                 0
# Davisville North                                                   1
# Parkdale, Roncesvalles                                             0
# St. James Town                                                     0
# The Annex, North Midtown, Yorkville                                0
#
#                                      Dundas West Chiropractic Clinic  \
# Neighbourhood
# Central Bay Street                                                 0
# Davisville North                                                   0
# Parkdale, Roncesvalles                                             1
# St. James Town                                                     0
# The Annex, North Midtown, Yorkville                                0
#
#                                      The Voice Clinic  Cystoscopy Clinic  \
# Neighbourhood
# Central Bay Street                                  0                  1
# Davisville North                                    0                  0
# Parkdale, Roncesvalles                              0                  0
# St. James Town                                      0                  0
# The Annex, North Midtown, Yorkville                 0                  0
#
#                                      Gastrointestinal Clinic  \
# Neighbourhood
# Central Bay Street                                         1
# Davisville North                                           0
# Parkdale, Roncesvalles                                     0
# St. James Town                                             0
# The Annex, North Midtown, Yorkville                        0
#
#                                      The Mindfulness Clinic  \
# Neighbourhood
# Central Bay Street                                        1
# Davisville North                                          0
# Parkdale, Roncesvalles                                    0
# St. James Town                                            0
# The Annex, North Midtown, Yorkville                       0
#
#                                      Toronto Foot Clinic  \
# Neighbourhood
# Central Bay Street                                     1
# Davisville North                                       0
# Parkdale, Roncesvalles                                 0
# St. James Town                                         0
# The Annex, North Midtown, Yorkville                    0
#
#                                      Grow Legally Marijuana Clinic and Consulting  \
# Neighbourhood
# Central Bay Street                                                              1
# Davisville North                                                                0
# Parkdale, Roncesvalles                                                          0
# St. James Town                                                                  0
# The Annex, North Midtown, Yorkville                                             0
#
#                                      Tuina Health Clinic
# Neighbourhood
# Central Bay Street                                     0
# Davisville North                                       0
# Parkdale, Roncesvalles                                 0
# St. James Town                                         1
# The Annex, North Midtown, Yorkville                    0

# %% [markdown]
# <h2>Clustering Initialization </h2>

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# run k-means clustering
kmeans = KMeans(n_clusters = 5, random_state = 0).fit(clinic_onehot)

# %%
means_df = pd.DataFrame(kmeans.cluster_centers_)
means_df.columns = clinic_onehot.columns
means_df.index = ['G1','G2','G3','G4','G5']
means_df['Total Sum'] = means_df.sum(axis = 1)
means_df.sort_values(axis = 0, by = ['Total Sum'], ascending=False)
# Out:
#     Rudd-PES Endoscopy Clinic  MCI Medical Clinic  Visage Clinic  \
# G3                        1.0                 1.0            0.0
# G1                        0.0                 0.0            1.0
# G2                        0.0                 0.0            0.0
# G4                        0.0                 0.0            0.0
# G5                        0.0                 0.0            0.0
#
#     Dundas University Health Clinic  Dundas West Chiropractic Clinic  \
# G3                              0.0                              0.0
# G1                              0.0                              0.0
# G2                              1.0                              0.0
# G4                              0.0                              1.0
# G5                              0.0                              0.0
#
#     The Voice Clinic  Cystoscopy Clinic  Gastrointestinal Clinic  \
# G3               0.0                1.0                      1.0
# G1               0.0                0.0                      0.0
# G2               0.0                0.0                      0.0
# G4               0.0                0.0                      0.0
# G5               0.0                0.0                      0.0
#
#     The Mindfulness Clinic  Toronto Foot Clinic  \
# G3                     1.0                  1.0
# G1                     0.0                  0.0
# G2                     0.0                  0.0
# G4                     0.0                  0.0
# G5                     0.0                  0.0
#
#     Grow Legally Marijuana Clinic and Consulting  Tuina Health Clinic  \
# G3                                           1.0                  0.0
# G1                                           0.0                  0.0
# G2                                           0.0                  0.0
# G4                                           0.0                  0.0
# G5                                           0.0                  1.0
#
#     Total Sum
# G3        7.0
# G1        1.0
# G2        1.0
# G4        1.0
# G5        1.0

# %%
neigh_summary = pd.DataFrame([means_df.index, 1 + kmeans.labels_]).T
neigh_summary.columns = ['Neighbourhood', 'Group']
neigh_summary
# Out:
#   Neighbourhood Group
# 0            G1     3
# 1            G2     2
# 2            G3     4
# 3            G4     5
# 4            G5     1

# %% [markdown]
# <h4> Best Neighborhood to open a clinic <h4>

# %%
neigh_summary[neigh_summary['Group'] == 5]
# Out:
#   Neighbourhood Group
# 3            G4     5

# %% [markdown]
# <h4> Second best neighborhood to open a clinic </h4>

# %%
neigh_summary[neigh_summary['Group'] == 1]
# Out:
#   Neighbourhood Group
# 4            G5     1

# %% [markdown]
# <h4> Third best neighborhood to open a clinic </h4>

# %%
neigh_summary[neigh_summary['Group'] == 4]
# Out:
#   Neighbourhood Group
# 2            G3     4

# %% [markdown]
# <h2>So the Doctor can open a clinic at St.James Town </h2>
